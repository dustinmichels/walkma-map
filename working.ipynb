# %%
import pandas as pd
import fiona
import geopandas as gpd

# %%
gdb_path = "data/townssurvey_gdb/townssurvey_gdb/townssurvey.gdb"

# %%
layers = fiona.listlayers(gdb_path)
layers
# Out:
# ['TOWNSSURVEY_ARC_GENCOAST',
#  'TOWNSSURVEY_POLYM_GENCOAST',
#  'TOWNSSURVEY_POLY',
#  'TOWNSSURVEY_PT',
#  'TOWNSSURVEY_POLYM',
#  'TOWNSSURVEY_ARC',
#  'T_1_DirtyAreas',
#  'T_1_PointErrors',
#  'T_1_LineErrors',
#  'T_1_PolyErrors',
#  'TOWNS_POLY_INCGW',
#  'TOWNS_POLY_AREACODE']

# %%
layer_name = "TOWNSSURVEY_POLYM"
gdf = gpd.read_file(gdb_path, layer=layer_name, engine="pyogrio")

# %%
len(gdf)
# Out:
# 351

# %%
df = pd.read_csv("data/Walk Audit Database - WalkMass Walk Audit Database.csv", header=1)

# %%
# Clean df
df['CITY/TOWN'] = df['CITY/TOWN'].str.strip()  # Remove whitespace
df['CITY/TOWN'] = df['CITY/TOWN'].str.upper()  # Standardize case

# %%
# Remove parentheses and content from CITY/TOWN column
df['CITY'] = df['CITY/TOWN'].str.replace(r'\s*\(.*?\)', '', regex=True)

# Extract neighborhood from parentheses into new column
df['NEIGHBORHOOD'] = df['CITY/TOWN'].str.extract(r'\((.*?)\)', expand=False)

# %%
# Clean gdf
gdf['TOWN'] = gdf['TOWN'].str.strip()
gdf['TOWN'] = gdf['TOWN'].str.upper()
gdf = gdf.rename(columns={'TOWN': 'CITY'})

# %%
merged_df = pd.merge(df, gdf, on='CITY', how='left')

# %%
len(merged_df)
# Out:
# 111

# %%
len(df)
# Out:
# 111

# %%
merged_df[merged_df['geometry'].isna()]
# Out:
#               CITY/TOWN  YEAR  \
# 41              HYANNIS  2018
# 45  LOWELL & CHELMSFORD  2019
#
#                                               SUMMARY  \
# 41  WalkMass conducted a walk audit along Route 13...
# 45  The Drum Hill Road/Westford Street Walk Audit,...
#
#                             LONG TERM RECOMMENDATIONS  \
# 41  - Redesign Route 132 using a complete streets ...
# 45  - Narrow travel lanes on Technology Dr to 10 f...
#
#                            SHORT TERM RECOMMENDATIONS  \
# 41  - Upgrade sidewalks and curb ramps on the sout...
# 45  - Add a raised crosswalk and MUTCD-compliant p...
#
#                STREETS, INNTERSECTIONS + AREA COVERED  \
# 41                         Route 132 (Iyannough Road)
# 45  Technology Dr, Drum Hill Rd, Westford St, & In...
#
#                                                THEMES VIEW  \
# 41  Connectivity, "Traffic Calming, Speed, Safety ...  PDF
# 45    "Traffic Calming, Speed, Safety ", Connectivity  PDF
#
#                                    FACILITATOR/AUTHOR                 CITY  \
# 41                  Stacey Beuttell & Brendan Kearney              HYANNIS
# 45  Stacey Beuttell, LeighAnne Taylor, & Ayesha Me...  LOWELL & CHELMSFORD
#
#     ... POP1990  POP2000 POP2010 POP2020  POPCH10_20  AREA_ACRES  AREA_SQMI  \
# 41  ...     NaN      NaN     NaN     NaN         NaN         NaN        NaN
# 45  ...     NaN      NaN     NaN     NaN         NaN         NaN        NaN
#
#     SHAPE_Length  SHAPE_Area  geometry
# 41           NaN         NaN      None
# 45           NaN         NaN      None
#
# [2 rows x 29 columns]
